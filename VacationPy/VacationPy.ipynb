# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0                   codrington -38.2667  141.9667     65.23
# 1        1                       albany  42.6001  -73.9662     45.68
# 2        2  edinburgh of the seven seas -37.0676  -12.3116     57.40
# 3        3                       namibe -15.1961   12.1522     64.87
# 4        4                      toliara -23.3500   43.6667     79.88
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        58         100       15.41      AU  1699415165
# 1        74         100        1.99      US  1699415165
# 2        84          87       26.71      SH  1699415166
# 3        81           5        2.57      AO  1699415166
# 4        58           5        4.43      MG  1699415166

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
plot = city_data_df.hvplot.points('Lng', 'Lat', geo=True, tiles='OSM', 
                                  hover_cols=['City', 'Humidity'], 
                                  size='Humidity', color='Humidity', 
                                  frame_height=400, frame_width=600)

# Display the map
plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Filter the DataFrame to only include cities with a maximum temperature less than 35 and humidity less than 20
ideal_weather_df = city_data_df[(city_data_df['Max Temp'] < 80) & (city_data_df['Humidity'] < 40)]

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display the DataFrame
ideal_weather_df
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 62        62            viedma -40.8135  -62.9967     57.54        37
# 103      103          douentza  14.9951   -2.9517     79.61        19
# 120      120              ghat  24.9647   10.1728     68.56        19
# 176      176        laojunmiao  39.8333   97.7333     38.08        30
# 199      199              hami  42.8000   93.4500     43.34        26
# 212      212      dalandzadgad  43.5708  104.4250     18.05        37
# 233      233             goure  13.9835   10.2704     74.28        15
# 234      234         ramhormoz  31.2800   49.6035     71.89        36
# 272      272         yermentau  51.6214   73.1069     42.01        29
# 284      284          zalingei  12.9096   23.4741     73.17        29
# 301      301          ardestan  33.3761   52.3694     58.71        35
# 335      335     puerto madryn -42.7692  -65.0385     59.65        35
# 341      341     shahr-e babak  30.1165   55.1186     55.47        33
# 342      342             naryn  41.4287   75.9911     44.37        30
# 343      343       al kharijah  25.4514   30.5464     70.97        34
# 346      346            bardai  11.6500    7.2333     68.77        24
# 354      354            agadez  19.7500   10.2500     69.13        19
# 379      379          tshabong -26.0500   22.4500     64.20        27
# 405      405            bousso  10.4795   16.7117     79.74        38
# 426      426         velingara  13.1500  -14.1167     74.17        31
# 449      449           xinyuan  37.3000   99.0000     32.04        19
# 455      455  general villegas -35.0328  -63.0125     56.64        29
# 460      460              brak  27.5496   14.2714     68.61        25
# 473      473             kidal  18.4411    1.4078     76.62        14
# 482      482   heroica caborca  30.7167 -112.1500     73.94        21
# 508      508         victorica -36.2151  -65.4359     56.48        37
# 516      516         goz beida  13.9500   20.5500     77.14        23
# 525      525              ziro  27.6333   93.8333     56.14        38
# 531      531             wuhai  39.6647  106.8122     42.08        24
# 532      532              vail  32.0479 -110.7120     71.28        18
# 551      551           biltine  14.5333   20.9167     77.85        22
#
#      Cloudiness  Wind Speed Country        Date
# 62            0       10.27      AR  1699415180
# 103          33        4.34      ML  1699415190
# 120           7        4.70      LY  1699415194
# 176         100        6.85      CN  1699415210
# 199           4       11.99      CN  1699415216
# 212          43        8.43      MN  1699415218
# 233          33        9.13      NE  1699415225
# 234           0        1.05      IR  1699415225
# 272          10        6.33      KZ  1699415235
# 284          71        7.99      SD  1699415238
# 301           0        4.45      IR  1699415242
# 335           3       27.38      AR  1699415251
# 341           0        2.75      IR  1699415178
# 342         100        2.04      KG  1699415252
# 343           0        7.94      EG  1699415252
# 346           3        6.91      NG  1699415253
# 354          36        1.79      NE  1699415255
# 379           2        8.84      BW  1699415261
# 405          60        3.78      TD  1699415268
# 426          45        3.20      SN  1699415273
# 449           0       19.60      CN  1699415278
# 455          67        8.84      AR  1699415280
# 460           1        6.55      LY  1699415085
# 473          25        8.88      ML  1699415285
# 482           0        1.45      MX  1699415102
# 508           0        7.38      AR  1699415294
# 516          86        9.01      TD  1699415296
# 525           0        0.22      IN  1699415300
# 531          70       20.54      CN  1699415301
# 532           0        8.01      US  1699415301
# 551          99       12.59      TD  1699415307

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Create a new DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat      Lng  Humidity Hotel Name
# 62       viedma      AR -40.8135 -62.9967        37
# 103    douentza      ML  14.9951  -2.9517        19
# 120        ghat      LY  24.9647  10.1728        19
# 176  laojunmiao      CN  39.8333  97.7333        30
# 199        hami      CN  42.8000  93.4500        26

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df

response = requests.get(base_url, params=params)
print(response.text)
hotel_data = response.json()
# Out:
# Starting hotel search
# viedma - nearest hotel: Níjar
# douentza - nearest hotel: No hotel found
# ghat - nearest hotel: فندق تاسيلي
# laojunmiao - nearest hotel: No hotel found
# hami - nearest hotel: Хами
# dalandzadgad - nearest hotel: Хан Уул буудал
# goure - nearest hotel: No hotel found
# ramhormoz - nearest hotel: No hotel found
# yermentau - nearest hotel: Достык
# zalingei - nearest hotel: No hotel found
# ardestan - nearest hotel: Tourism Hotel
# puerto madryn - nearest hotel: Hotel Gran Palace
# shahr-e babak - nearest hotel: هتل شهرداری
# naryn - nearest hotel: Ала-Тоо
# al kharijah - nearest hotel: Kharga Hotel
# bardai - nearest hotel: No hotel found
# agadez - nearest hotel: No hotel found
# tshabong - nearest hotel: No hotel found
# bousso - nearest hotel: No hotel found
# velingara - nearest hotel: Campement Touristique
# xinyuan - nearest hotel: No hotel found
# general villegas - nearest hotel: Rucalén
# brak - nearest hotel: فندق براك السياحي
# kidal - nearest hotel: No hotel found
# heroica caborca - nearest hotel: Hotel Posada del Desierto
# victorica - nearest hotel: Hotel Mazamet
# goz beida - nearest hotel: No hotel found
# ziro - nearest hotel: No hotel found
# wuhai - nearest hotel: Binhe International Hotel
# vail - nearest hotel: Hampton Inn & Suites Tucson Tech Park
# biltine - nearest hotel: فندق ثلاث نجوم بلتن
# {"type":"FeatureCollection","features":[{"type":"Feature","properties":{"name":"فندق ثلاث نجوم بلتن","country":"Chad","country_code":"td","state":"Wadi Fira","city":"Biltine","street":"Abeche - Biltine National Road","lon":20.914497554685035,"lat":14.5275029,"state_code":"WF","formatted":"فندق ثلاث نجوم بلتن, Abeche - Biltine National Road, Biltine, Chad","address_line1":"فندق ثلاث نجوم بلتن","address_line2":"Abeche - Biltine National Road, Biltine, Chad","categories":["accommodation","accommodation.hotel"],"details":["details"],"datasource":{"sourcename":"openstreetmap","attribution":"© OpenStreetMap contributors","license":"Open Database Licence","url":"https://www.openstreetmap.org/copyright","raw":{"name":"فندق ثلاث نجوم بلتن","osm_id":503513905,"name:ar":"فندق ثلاث نجوم بلتن","tourism":"hotel","osm_type":"w","addr:city":"بلتن"}},"distance":612,"place_id":"51d049399a1cea3440593fe3f98d150e2d40f00102f9013103031e00000000920323d981d986d8afd98220d8abd984d8a7d8ab20d986d8acd988d98520d8a8d984d8aad986"},"geometry":{"type":"Point","coordinates":[20.914498938547524,14.527508198503368]}},{"type":"Feature","properties":{"country":"Chad","country_code":"td","state":"Wadi Fira","city":"Biltine","street":"Abeche - Biltine National Road","lon":20.914375843316485,"lat":14.52752215,"state_code":"WF","formatted":"Abeche - Biltine National Road, Biltine, Chad","address_line1":"Abeche - Biltine National Road","address_line2":"Biltine, Chad","categories":["accommodation","accommodation.hotel"],"details":[],"datasource":{"sourcename":"openstreetmap","attribution":"© OpenStreetMap contributors","license":"Open Database Licence","url":"https://www.openstreetmap.org/copyright","raw":{"osm_id":538772319,"tourism":"hotel","osm_type":"w"}},"distance":644,"place_id":"511e9c983f13ea344059557a1aaa170e2d40f00102f9015f031d2000000000"},"geometry":{"type":"Point","coordinates":[20.914356207617054,14.527524295551453]}}]}

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
plot = hotel_df.hvplot.points('Lng', 'Lat', geo=True, tiles='OSM', 
                              hover_cols=['City', 'Country', 'Hotel Name'], 
                              frame_height=400, frame_width=600)

# Display the map
plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Country,Hotel Name)
